# %% [markdown]
# <a href="https://colab.research.google.com/github/mjss26/EMSC2010-W9-L1-MSS/blob/main/EMSC2010_W9_L1_NB1_MSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB1
# Model Earth's surface temperature (in Kelvin) using a zero-dimensional energy balance model without an atmosphere.
#
# $T_e = \left[ \frac{S}{4 \alpha} (1-A)\right]^{1/4}$
#
# where:
# * $T_e$ is Earth's surface temperature in Kelvin
# * $S$ is the solar flux (1366 W/m$^2$)
# * $A$ is albedo (currently around 0.3)
# * $\alpha$ is the Stefan-Boltmann constant (5.67E-8 W/m$^2$/K$^4$)

# %%
T_e = (1366/(4*5.67e-8)*(1-0.3))**(1/4) # in kelin not celcius # so answer is in negative degree celcius
print(T_e)
# Out:
# 254.81584054796193

# %%
#atmosphere will raise temp

# %%
#trial with 0 albedo - ie all ice sheet are melted no reflecting

T_e = (1366/(4*5.67e-8)*(1-0))**(1/4) # in kelin not celcius # so answer is in negative degree celcius
print(T_e)
# Out:
# 278.5812689476053

# %%
#trial with larger solar flux (normal albedo) - 10% less

T_e = (1229.4/(4*5.67e-8)*(1-0.3))**(1/4) # in kelin not celcius # so answer is in negative degree celcius
print(T_e)
# Out:
# 248.19158334222595
